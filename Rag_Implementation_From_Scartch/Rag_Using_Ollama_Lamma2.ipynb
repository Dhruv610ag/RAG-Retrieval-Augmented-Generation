# %% [markdown]
# ### INGESTION->RETRIEVAL->GENERATION(RAG PIPELINE)

# %%
corpus_of_documents = [
    "Take a leisurely walk in the park and enjoy the fresh air.",
    "Visit a local museum and discover something new.",
    "Attend a live music concert and feel the rhythm.",
    "Go for a hike and admire the natural scenery.",
    "Have a picnic with friends and share some laughs.",
    "Explore a new cuisine by dining at an ethnic restaurant.",
    "Take a yoga class and stretch your body and mind.",
    "Join a local sports league and enjoy some friendly competition.",
    "Attend a workshop or lecture on a topic you're interested in.",
    "Visit an amusement park and ride the roller coasters."
]

# %%
corpus_of_documents
# Out:
# ['Take a leisurely walk in the park and enjoy the fresh air.',
#  'Visit a local museum and discover something new.',
#  'Attend a live music concert and feel the rhythm.',
#  'Go for a hike and admire the natural scenery.',
#  'Have a picnic with friends and share some laughs.',
#  'Explore a new cuisine by dining at an ethnic restaurant.',
#  'Take a yoga class and stretch your body and mind.',
#  'Join a local sports league and enjoy some friendly competition.',
#  "Attend a workshop or lecture on a topic you're interested in.",
#  'Visit an amusement park and ride the roller coasters.']

# %%
user_query="i am indian and i live in india"

# %%
doc="india is a country for indians and for everyone"

# %%
from collections import Counter
import math

# %%
query_token=user_query.lower().split(" ")

# %%
document_token=doc.lower().split(" ")

# %%
query_counter=Counter(query_token)

# %%
document_counter=Counter(document_token)

# %%
lst=[]
for token in query_counter.keys():
    lst.append(query_counter[token])

# %%
#sentence vector 
lst
# Out:
# [2, 1, 1, 1, 1, 1, 1]

# %%
mylst=[]
for tokens in query_counter.keys() & document_counter.keys():
    mylst.append(query_counter[token]*document_counter[token])#as we are going to perform the dot product for the query and document and in this we have taken the word level similarity rather than the sentence level similarity

# %%
mylst
# Out:
# [1, 1]

# %%
dot_prod=sum(mylst)

# %%
query_magnitude=math.sqrt(sum(query_counter[token]**2 for token in query_counter))

# %%
query_magnitude
# Out:
# 3.1622776601683795

# %%
document_magnitude=math.sqrt(sum(document_counter[token]**2 for token in document_counter))

# %%
document_magnitude
# Out:
# 3.3166247903554

# %%
similarity=(dot_prod)/(query_magnitude*document_magnitude)

# %%
similarity
# Out:
# 0.19069251784911848

# %%
user_query="i love to do yoga and meditation"
document="Yoga is good for physical strength and meditation is good for mental strength"

# %%
def cosine_similarity(query,document):
    query_token=query.lower().split(" ")
    doc_token=document.lower().split(" ")

    query_counter=Counter(query_token)
    doc_counter=Counter(doc_token)

    dot_product=sum(query_counter[token]*doc_counter[token] for token in query_counter.keys() & doc_counter.keys())

    query_magnitude=math.sqrt(sum(query_counter[token]**2 for token in query_counter))
    doc_magnitude=math.sqrt(sum(doc_counter[token]**2 for token in doc_counter))

    similarity=(dot_product)/(query_magnitude*doc_magnitude)

    return similarity

# %%
print(cosine_similarity(user_query,document))
# Out:
# 0.24743582965269675

# %%
def return_response(query,corpus):
    similarities=[]
    for docs in corpus:
        similarity=cosine_similarity(query,doc)
        similarities.append(similarity)
    return corpus_of_documents[similarities.index(max(similarities))]

# %%
user_query="i llike fresh air"

# %%
return_response(user_query,corpus_of_documents)
# Out:
# 'Take a leisurely walk in the park and enjoy the fresh air.'
